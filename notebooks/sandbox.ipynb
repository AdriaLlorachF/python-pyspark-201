# %% [markdown]
# # NovaShop — sandbox
#
# Abre este notebook **desde la raíz del repo**. Sigue el guion del módulo en `labs/`.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("labs/_shared").resolve()))
from session import get_spark

spark = get_spark("novashop")
spark.version
